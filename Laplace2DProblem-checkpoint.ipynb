# %% [markdown]
# # Solve Laplace's equation in 2 dimensions
# ##### by: Krystifer Campos Muñoz - Universidad del Valle

# %% [markdown]
# This code solves the Laplace equation for potentials in internal regions with boundary conditions using numerical methods. Each block of code is explained step by step.

# %% [markdown]
# First, import useful libraries. I use 'turtle' to allow the user to draw custom closed loops with the mouse. '%matplotlib notebook' is used to create interactive graphics, 'numpy' is used to create 2d arrays, from 'mpl_toolkits' I use 'mplot3d' to do a 3d plot for the potential. Finally from 'scipy.ndimage' I use 'convolve' to make the convolution of two matrices, and 'generate_binary_structure' is used to create the kernel of the convolution.

# %%
import turtle                                                                 
import numpy as np 
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d 
from scipy.ndimage import convolve, generate_binary_structure

# %% [markdown]
# The first part consists of the use of turtle, this library allows to declare commands to draw figures in a window, which opens automatically when the line 'name= turtle.Turtle()' is executed. The commands used are documented in [turtle](https://docs.python.org/3/library/turtle.html).

# %% [markdown]
# Please read the comments of each function in the execution flow shown for a better understanding:  startTurtle -> showTurtle -> message -> drag -> close.

# %% [markdown]
# ------------------------------------------------------------------------------------

# %% [markdown]
# #### Drawing window

# %%
def drag(i,j):
    tur.ondrag(None)                    
    tur.setheading(tur.towards(i, j))          # set direction of cursor
    tur.goto(i, j)                             # move cursor towards that direction 
    X = int( (tur.pos()+(150,150))[0] )        # get the position of the cursor as a 2-tuple (x,y) in pixels, sum 150 to move the origin 
    Y = int( (tur.pos()+(150,150))[1] )        # of our following plt graphs at the bottom left, and take those positions as integers          
    boundaryConditions[Y,X] = float(potential) # set the value of the boundary conditions array to 'potential' entered by the user at the positions of the dragged cursor
    tur.ondrag(drag)                           # recursion for a continuous dragging
    turtle.TurtleScreen._RUNNING = True        # prevent turtle window initialization errors

# %%
def message(i,j):
    global potential            # define a global variable
                                # input text with the value of the potential at the next line
    potential = turtle.textinput('Potential', 'Set the potential for the next barrier')     
    tur.ondrag(drag)             # If the cursor is dragged call the function 'drag'

# %%
def showTurtle(i,j):    
    tur.penup()                # don't draw when turtle moves
    tur.goto(i,j)              # move the turtle to the location (i,j)
    tur.showturtle()           # make the turtle visible
    tur.pendown()              # draw when turtle moves

# %%
def close(i,j):
    turtle.Screen().bye()                     # close the drawing window
    turtle.TurtleScreen._RUNNING = True       # prevent turtle window initialization errors

# %%
def startTurtle(grid):    
    global boundaryConditions      # Global variables can be used in all the notebook
    global tur  
    boundaryConditions = grid      # set the matrix of boundary conditions 
    tur= turtle.Turtle()           # creates the turtle object
    tur.shape('circle')            # set the cursor shape as a circle
    tur.pensize(10)                # set the cursor size 
    tur.shapesize(.5,.5,.5)        # set the cursor shape size 
    tur.pencolor('purple')         # set the cursor corlor
    tur.hideturtle()               # hide the cursor
    ws = turtle.Screen()           # initialize the screen for drawing
    ws.setup(300, 300)             # set the screen size in pixels
    ws.screensize(300, 300)        # set the available area for drawing in pixels
    ws.bgcolor('grey')             # set the background color for the window
    tur.speed('fastest')           # set the speed of the cursor
    ws.onclick(showTurtle,1)       # event that calls the function 'showTurtle' when the left button of user mouse is clicked
    tur.ondrag(drag)               # event that calls the function 'drag' when user drags the cursor
    tur.onrelease(message)         # event that calls the 'message' function when the user releases the mouse to start drawing a new line
    ws.onclick(close,3)            # event that calls the 'close' function when the right mouse button is clicked
    ws.mainloop()                  # put everything in a loop

# %% [markdown]
# ------------------------------------------------------------------------------------

# %% [markdown]
# #### set boundary conditions  and initial guess

# %% [markdown]
# When executing the following line, a window will appear, click on it and answer the message with a number, indicating the value of the potential in the line that you are going to draw. Then drag your cursor to draw the line. Once you released the cursor, you need to reply to the next prompt with a number to set the potential of the next line to draw. Repeat the process until you get a closed loop, cancel the last prompt (since you're done drawing) and right-click to save the array (don't close the window, it will close automatically when you right-click). Recommendations: 1. To get a good drawing you should draw the lines slowly. 2. The sides with zero potential can be explicitly indicated by entering '0' in the dialog box. 3. Your can draw one figure inside another to simulate conductors at constant potentials.

# %%
x, y = np.meshgrid(np.arange(0,300,1),np.arange(0,300,1))            # 2d grid of cartesian coordinates
grid = np.zeros((300,300)) 
#grid = x/2 -2                                                       # set an initial guess

startTurtle(grid)              # Execute this to set boundary lines

# %% [markdown]
# Next image shows the boundary conditions, (in this example I drew a 2d spherical capacitor inside a box with zero potential walls).

# %%
# %matplotlib inline
fig1 = plt.figure(figsize=(5,5))
plt.imshow(boundaryConditions, cmap='PuBuGn_r', origin= 'lower', aspect='auto')
plt.colorbar()
plt.show()

# %% [markdown]
# -----------------------------------------------------------------------------

# %% [markdown]
# #### Convolution

# %% [markdown]
# It can be shown that the solutions of Laplace's equation satisfy the equality:

# %% [markdown]
# $V(x_{i},y_{j})=\frac{1}{4}\left ( V(x_{i+1},y_{j})+ V(x_{i-1},y_{j}) + V(x_{i},y_{j+1})+ V(x_{i},y_{j-1}) \right )$

# %% [markdown]
# That is, we don't know the actual solution, but we know that every solution has that property, so we can find each value of the potential in terms of the values at neighboring points. On a 2D grid, the last equation says that we should take the average of the nearest neighbors (above, below, to the left and to the right, excluding diagonal neighbors) to obtain the value of the potential at some point.
# The relaxation method is applied to the boundary condition matrix, where we update the matrix by replacing each element with the average of its nearest neighbors. This process is repeated using the updated matrix. After a given number of iterations, the matrix must converge, this is known when the change from one matrix to another is negligible, by the uniqueness of potential theorem, this is the solution to the Laplace equation in that interior region with the specified boundary conditions.

# %% [markdown]
# ##### A quick introduction can be found in [Griffiths, chapter 3](https://archive.org/details/introduction-to-electrodynamics-d-j-griffiths-4ed).

# %% [markdown]
# To take the desired average, we can make a convolution of the matrix of boundary conditions with the next kernel matrix:

# %%
gridUpdated = np.zeros((300,300))
kernel = generate_binary_structure(2,1).astype(float)/4.
kernel[1,1] = 0
kernel               # By the definition of matrix covolution, this will give the desired result
# Out:
# array([[0.  , 0.25, 0.  ],
#        [0.25, 0.  , 0.25],
#        [0.  , 0.25, 0.  ]])

# %% [markdown]
# The following is the iteration process, where the stopping condition is given by the maximum absolute error between the elements of each array, we accept a solution when this error is less than $10^{-5}$, (it takes a while to converge ).

# %%
error=1   # just to enter in the loop
while(error>10**(-5)):
    gridUpdated = convolve(grid, kernel, mode = 'constant',  cval = 0.0)
    gridUpdated[boundaryConditions != 0] = boundaryConditions[boundaryConditions != 0]   # This keep the boundary potential fix on each iteration  
    error = np.max(np.abs(gridUpdated-grid))
    grid = gridUpdated
print('error: ',error)
# Out:
# error:  9.998976743030852e-06

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Results

# %% [markdown]
# Warning: The solution is valid for regions that have well-established boundary conditions, such as the interior points of a closed path. Therefore, even if the solution is displayed on the entire grid, uniqueness is guaranteed only at points inside closed regions.

# %%
# %matplotlib inline
fig2 = plt.figure(figsize=(5,5))
plt.imshow(grid, cmap='PuBuGn_r', origin= 'lower', aspect='auto')
plt.colorbar()
plt.show()

# %%
# %matplotlib notebook
fig3 = plt.figure(figsize=(10,10))
x, y = np.meshgrid(np.arange(0,300,1),np.arange(0,300,1))

ax = plt.axes(projection='3d')
ax.plot_surface(x, y, grid, cmap = 'PuBuGn_r')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('Potential');
# Out:
# <img src="data:image/png;base64,..." width="720.0000190734868">

# %% [markdown]
# --------------------------------------------------------------------------------------------

# %% [markdown]
# Thanks for reading.
